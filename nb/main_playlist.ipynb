# %%
#export

from pytube import Playlist
from download_youtube_subtitle import main

# %%
#test_export

url = ('https://www.youtube.com/playlist?list=PLS1QulWo1RIaJECMeUT4LFwJ-ghgoSH6n')
p = Playlist(url)
for url in p.video_urls[:3]:
    print(url)
main.main(url, )
# Out:
# https://www.youtube.com/watch?v=41qgdwd3zAg
# https://www.youtube.com/watch?v=Lbs7vmx3YwU
# https://www.youtube.com/watch?v=YtX-Rmoea0M
# INFO:  available caption(s):
# INFO:  #0  ✔ as original code="a.en" name="English (auto-generated)" automatically generated by youtube
# INFO:  given by --caption_num default to 0 as original
# INFO:  you may use --caption_num_second intead of --translation to spefify translation transript
# INFO:  Save to  Python_Tutorial_for_Beginners_3_-_Variables_and_Inputs.txt

# %%
#export
from progiter import ProgIter as tqdm
from download_youtube_subtitle.main import Union, fire
def main_playlist(playlist_url:str, 
    start=0,
    end=None,
    translation:Union[str,bool]=None, 
    caption_num:int=0, 
    caption_num_second:int=None,
    output_file:str=None, 
    save_to_file:bool=True,
    to_json:bool=False, 
    remove_font_tag:bool=True
):
    """
    download youtube closed caption(subtitles) by playlist. To figure most of params, please use dl-youtube-cc to download one video first before downloading the entire playlist.
    
    Examples:
    dl-youtube-cc-playlist -h # to see this helpful infomation
    dl-youtube-cc-playlist PLS1QulWo1RIaJECMeUT4LFwJ-ghgoSH6n 
    dl-youtube-cc-playlist PLS1QulWo1RIaJECMeUT4LFwJ-ghgoSH6n 0 3 # download the first 3 videos
    dl-youtube-cc-playlist https://www.youtube.com/playlist?list=PLS1QulWo1RIaJECMeUT4LFwJ-ghgoSH6n
    
    Argument:
    playlist_url : the playlist link or the id of youtube playlist, the string after 'list=' in the url
    start: the index number in the playlist to start downloading, starting from 0
    end: the index number in the playlist to end downloading, exclusively
    translation : which will be displayed as original transcript, default to 'zh-Hans' for simplified Chinese, see ./lang_code.json for full list, or pass False to disable translation
    caption_num : choose the caption which will be displayed as original transcript
    caption_num_second : will surpass translation option, choose the caption which will be displayed as translation transcript
    output_file : default to video title
    save_to_file : pass False to print in console
    to_json: pass True to export caption to json
    remove_font_tag: remove font tag
    """    
    if "https:" not in playlist_url:
        playlist_url = "https://www.youtube.com/playlist?list="+playlist_url
    p = Playlist(playlist_url)
    if end is None: end=len(p.video_urls)
    for url in tqdm(p.video_urls[start:end]):
        main.main(url, 
            translation,
            caption_num,
            caption_num_second,
            output_file,
            save_to_file,
            to_json,
            remove_font_tag,
        )

# %%
#export
from functools import partial
import download_youtube_subtitle.common as common
def set_fire(fn):
    if common.IN_TRAVIS or common.IN_JUPYTER:
        return 
    fire.Fire(fn)
if __name__ == '__main__':
    if common.IN_TRAVIS or common.IN_JUPYTER:
        pass
    else :
        set_fire(main_playlist)
fire_main_playlist = partial(set_fire, main_playlist)

# %%
# test_export
main_playlist('https://www.youtube.com/playlist?list=PLS1QulWo1RIaJECMeUT4LFwJ-ghgoSH6n', end=4)
# Out:
#  0.00% 0/4... rate=0 Hz, eta=?, total=0:00:00INFO:  available caption(s):
# INFO:  #0  ✔ as original code="a.en" name="English (auto-generated)" automatically generated by youtube
# INFO:  given by --caption_num default to 0 as original
# INFO:  you may use --caption_num_second intead of --translation to spefify translation transript
# INFO:  Save to  Python_Tutorial_for_Beginners_1_-_Getting_Started_and_Installing_Python_For_Absolute_Beginners.txt
# INFO:  available caption(s):
# INFO:  #0  ✔ as original code="a.en" name="English (auto-generated)" automatically generated by youtube
# INFO:  given by --caption_num default to 0 as original
# INFO:  you may use --caption_num_second intead of --translation to spefify translation transript
# INFO:  Save to  Python_Tutorial_for_Beginners_2_-_Numbers_and_Math_in_Python.txt
#  50.00% 2/4... rate=0.51 Hz, eta=0:00:03, total=0:00:03INFO:  available caption(s):
# INFO:  #0  ✔ as original code="a.en" name="English (auto-generated)" automatically generated by youtube
# INFO:  given by --caption_num default to 0 as original
# INFO:  you may use --caption_num_second intead of --translation to spefify translation transript
# INFO:  Save to  Python_Tutorial_for_Beginners_3_-_Variables_and_Inputs.txt
# INFO:  available caption(s):
# INFO:  #0  ✔ as original code="a.en" name="English (auto-generated)" automatically generated by youtube
# INFO:  given by --caption_num default to 0 as original
# INFO:  you may use --caption_num_second intead of --translation to spefify translation transript
# INFO:  Save to  Python_Tutorial_for_Beginners_4_-_Built-in_Modules_and_Functions.txt
#  100.00% 4/4... rate=0.49 Hz, eta=0:00:00, total=0:00:08

# %%
# test_export
main_playlist('PLS1QulWo1RIaJECMeUT4LFwJ-ghgoSH6n', start=3, end=5)
# Out:
#  0.00% 0/2... rate=0 Hz, eta=?, total=0:00:00INFO:  available caption(s):
# INFO:  #0  ✔ as original code="a.en" name="English (auto-generated)" automatically generated by youtube
# INFO:  given by --caption_num default to 0 as original
# INFO:  you may use --caption_num_second intead of --translation to spefify translation transript
# INFO:  Save to  Python_Tutorial_for_Beginners_4_-_Built-in_Modules_and_Functions.txt
#  50.00% 1/2... rate=0.47 Hz, eta=0:00:02, total=0:00:02INFO:  available caption(s):
# INFO:  #0  ✔ as original code="a.en" name="English (auto-generated)" automatically generated by youtube
# INFO:  given by --caption_num default to 0 as original
# INFO:  you may use --caption_num_second intead of --translation to spefify translation transript
# INFO:  Save to  Python_Tutorial_for_Beginners_5_-_Save_and_Run_Python_files_.py.txt
#  100.00% 2/2... rate=0.47 Hz, eta=0:00:00, total=0:00:04

# %%
common.save_and_export_notebook('main_playlist')
# Out:
# Converted main_playlist.ipynb to ../download_youtube_subtitle/main_playlist.py
# Converted main_playlist.ipynb to ../tests/test_main_playlist.py
